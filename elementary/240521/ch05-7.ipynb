# %%
# 외부 라이브러리 Faker 사용해보기
# 사전 작업 -> pip install Faker # 외부 라이브러리 Faker설치

from faker import Faker

fake = Faker('ko-KR')
print(fake.name())

print(fake.address())

test_data = [(fake.name(), fake.address()) for i in range(30)]
print(test_data)
# Out:
# 박영숙
# 부산광역시 동작구 학동가 (영희김리)
# [('류종수', '광주광역시 영등포구 강남대로'), ('김윤서', '부산광역시 은평구 서초중앙5로 (정호김동)'), ('김서현', '대전광역시 양천구 서초중앙거리'), ('권정숙', '충청남도 광주시 압구정329로 (은정한유마을)'), ('김하윤', '인천광역시 서초구 개포61로'), ('이현지', '경상북도 성남시 중원구 압구정길'), ('최정순', '전라남도 성남시 중원구 역삼2로'), ('송서현', '대구광역시 용산구 압구정550길 (준영김동)'), ('황미정', '부산광역시 노원구 가락9거리'), ('고영수', '전라남도 고양시 일산동구 반포대로'), ('안정자', '광주광역시 금천구 압구정580거리 (수진김면)'), ('손경수', '광주광역시 강서구 언주거리 (예진김이리)'), ('이현지', '충청남도 용인시 처인구 반포대592거리'), ('서미영', '전라북도 광명시 반포대로 (정남송리)'), ('조현숙', '제주특별자치도 부천시 오정구 가락525로'), ('박예진', '울산광역시 서구 역삼6로'), ('고서연', '경기도 하남시 양재천56거리'), ('조서영', '경기도 부천시 소사구 영동대1가 (정훈배읍)'), ('민주원', '인천광역시 영등포구 도산대거리 (현정이안동)'), ('김상철', '경상북도 평창군 학동가 (정훈김동)'), ('김병철', '대전광역시 용산구 학동거리 (은정류김면)'), ('윤은정', '대전광역시 동작구 논현794거리 (영미김김읍)'), ('김정숙', '충청북도 김포시 석촌호수가 (준서박면)'), ('고정희', '대전광역시 구로구 역삼길'), ('박민서', '경기도 의왕시 테헤란로 (현숙박이리)'), ('이정웅', '울산광역시 성동구 강남대길 (예진신양리)'), ('강영철', '제주특별자치도 안양시 만안구 가락0거리 (미정장송읍)'), ('김미숙', '인천광역시 금천구 논현가'), ('이지영', '경기도 파주시 삼성길'), ('서현준', '제주특별자치도 충주시 오금1거리')]
